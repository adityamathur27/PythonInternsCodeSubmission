# %% [markdown]
# <a href="https://colab.research.google.com/github/Hackveda/PythonInternsCodeSubmission/blob/main/Digital_Marketing_Tool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  requests
import pandas as pd
import json

from datetime import date,timedelta

# %%
ques_list = []

word = input("Enter the Word:")
word1 = word

site_list = ["quora.com"]
for site in site_list:
  word = word + "site:"+site
  print(word)

  #key = AIzaSyC5XUl7smAx7Ugk90YB4dtXH1jYgJeDFcc    &&    cx = cx=457f8d5d8b98943b2
  google_url = "https://www.googleapis.com/customsearch/v1/?key=AIzaSyC5XUl7smAx7Ugk90YB4dtXH1jYgJeDFcc&cx=457f8d5d8b98943b2"
  google_url = google_url + "&q=" + word
  #print("Google URL:" + google_url)
  response = requests.get(google_url)
  #print("Response:" + str(response.text))

  json_response = json.loads(response.text)
  #search_time = json_response["searchInformation"]["searchTime"]
  #print("Search Time is:",search_time)
  total_results = int(json_response["searchInformation"]["totalResults"])
  #print("Total Result is",total_results)

  #from here part 2 starts
  #next_index = json_response["queries"] ["nextPage"] [0] ["startIndex"]
  total_pages = round(total_results / 10)

  try:
    for item in json_response["items"]:
      title = item["title"]
      title = title.replace("- Quora","")
      ques_list.append(title)
      #print(title)

  except Exception as e:
    pass

  word = word1

#ques_list
ques_dict = {"Questions": ques_list}
df = pd.DataFrame(data=ques_dict)
df
# Out:
# Enter the Word:best movies
# best moviessite:quora.com
#                                            Questions
# 0  What is the best website to watch online movie...
# 1  Order To Watch Star Trek Movies Site Www.quora...
# 2  Which is the best offshore host for movies site?
# 3  Streaming Sites: Are They Illegal? How Do They...
# 4   Which is the best ad network for a movies site?
# 5  Types of Sites That Have Quality AdSense Reven...
# 6     What are the best sites for streaming movies?
# 7    GoPro Awards | Video & Photo Challenges | GoPro
# 8    Is It illegal to create an online movies site?
# 9  Good Luck to You, Leo Grande movie review (202...

# %%
df.to_csv(word1 + "_questions.csv")
