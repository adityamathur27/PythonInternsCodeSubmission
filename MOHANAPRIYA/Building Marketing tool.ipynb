# %%
import requests # library for http requests in python
import pandas as pd # library to represent responses in Table
import json # library for data representation during transmission

from datetime import date, timedelta # library for date management

# %%
# Global variables
questions_list=[]

# Take keyword from user
keyword=input("Enter a keyword: ")
keyword1 = keyword

# Search keyword on quora
#keyword=keyword+"site:quora.com site:reditt.com" # String concatenation

# Multiple site search
site_list=["quora.com", "reditt.com"]
for site in site_list:
    keyword=keyword + " site:"+site
    #print(keyword) 
    
    # Search on Googel API's and key
    # key file= AIzaSyCZ0_LMyd03jdYq3mMmGFxtMJbo4bKjHCY
    google_url = "https://www.googleapis.com/customsearch/v1/?key=AIzaSyCZ0_LMyd03jdYq3mMmGFxtMJbo4bKjHCY&cx=50e55625bf8094c34"
    google_url= google_url +"&q= " + keyword
    #print("Googel URL: "+ google_url)
    
    # Send a network request to google
    response = requests.get(google_url)
    #print("Response: "+ str(response.text))
    
    # Convert Response string into JSON object
    json_response=json.loads(response.text)
    #search_time=json_response["searchInformation"]["searchTime"]
    #print("Search time taken is",search_time)
    
    total_results=int(json_response["searchInformation"]["totalResults"])
    #print("Total results are",total_results)
    
    # Get the start index of next page
    #next_index=json_response["queries"]["nextPage"][0]["startIndex"]
    
    # Loop through all the responses from google
    total_pages= round(total_results/10)
    
    try:
        # Loop through the responses
        for item in json_response["items"]:
            title=item["title"]
            title=title.replace(" - Quora", "")
            questions_list.append(title)
            #print(title)
                
        # Send a new 
        
    
    except Exception as e:
        pass
        #print("Exception",e)
    
    
    # reset the keyword
    keyword=keyword1
questions_dict={"Questions": questions_list}
df=pd.DataFrame(data=questions_dict)
df
# Out:
# Enter a keyword: python interview
#                                            Questions
# 0       How should I prepare for a Python interview?
# 1  How to prepare for a Python interview for expe...
# 2  Can I use Python in coding interviews at compa...
# 3      Can you code in Python for Amazon interviews?
# 4  Is it okay to use Python when interviewing at ...
# 5  Which is best for a Google interview, Python o...
# 6            How to crack Python interview questions
# 7          What are good Python interview questions?
# 8  Which language should I use for my interview, ...
# 9    How to start preparing for the Python interview

# %%
# Export the data to a file
df.to_csv(keyword1 + "_questions.csv")
