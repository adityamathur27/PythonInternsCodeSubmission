# %%
#Python storage location
# !which python
# Out:
# /usr/local/bin/python

# %%
#Check the current python version
# !python --version
# Out:
# Python 3.7.13

# %%
2 + 2
# Out:
# 4

# %%
20 - 10 * 2
# Out:
# 0

# %%
#Using brackets in number statements
(20-10) * 2
# Out:
# 20

# %%
#Divide 5 by 3
5/3
# Out:
# 1.6666666666666667

# %%
#checking the types of numbers
a = 1
b = 1.0

# %%
#check the type of variable a
type(a)
# Out:
# int

# %%
#check the type of variable a
type(b)
# Out:
# float

# %%
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %%
#check return type of operators
a = 1 + 1
print(type(a))

b = 1 - 1
print(type(b))

c = 1 * 1
print(type(c))

d = 1 / 1
print(type(d))

e = 1 // 1 #Perform floor division
print(type(e))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>

# %%
# Return the remainder of the division
f = 5 % 3 #is used to get the remainder
print(f)
# Out:
# 2

# %%
#Calculating powers of Numbers in python( ** )
# Suppose : Calculate 2 raise to the poers of 2
g = 2 ** 2
print(g)
# Out:
# 4

# %%
h = 2 ** 10
print(h)
# Out:
# 1024

# %%
#Name Neetu is not defined
Neetu = 2 * 5 + 10 - 3
print(Neetu)
# Out:
# 17

# %%
#Print the last calculated value in Python
10 * 2
# Out:
# 20

# %%
_
# Out:
# 20

# %%
# !pip install kora
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 57 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 10.4 MB/s
# ...

# %%
import kora.install.py38
# Out:
# https://8814-34-73-248-128.ngrok.io
