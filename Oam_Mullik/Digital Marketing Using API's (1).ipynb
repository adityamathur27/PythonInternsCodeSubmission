# %%
import requests 
import pandas as pd 
import json 
from datetime import date, timedelta

# %%
#global variable
questions_list = []

# Take Keyword From user
keyword=input("Enter a Keyword: ")

site_list=["quora.com","reditt.com"]

for site in site_list:
    keyword1 = keyword + " site:"+site
    print(keyword1)
    
    # key file - AIzaSyBUZzk9_kZQhEA9U67rBJO-zK-nFmsh-K8
    google_url= "https://www.googleapis.com/customsearch/v1/?key=AIzaSyB0fpT6tagI4Kgfy15h28awDRjk6kE2hXk&cx=012773643409177149611:giuhxzmolrc"
    
    google_url= google_url + "&q=" + keyword1
    #print("Google url: ",google_url)
    
    response=requests.get(google_url)
    #print("Response: ", response.text)
    
    json_response = json.loads(response.text)
    #search_time = json_response["searchInformation"]["searchTime"]
    #print("Search time taken is", search_time)
    
    total_results = int(json_response["searchInformation"]["totalResults"])
    #print("Total results are: ",total_results)
    
    #get the start index of next page
    #next_Index=json_response["queries"]["nextPage"][0]["startIndex"]
    
    #loop through all the esponses from google
    total_pages=round(total_results/10)
    
    try:
        for item in json_response["items"]:
            title = item["title"]
            title = title.replace("- Quora","")
            questions_list.append(title)
                
    except Exception as e:
        pass
    
    #reset the keyword
    keyword1=""
        
# questions_list
questions_dict= {"Questions" : questions_list}
df = pd.DataFrame(data=questions_dict)
df
# Out:
# Enter a Keyword: 5 star hotels
# 5 star hotels site:quora.com
# 5 star hotels site:reditt.com
#                                            Questions
# 0  What are things about 5-star hotels that they ...
# 1  Is it okay to take the bathrobe from 5 star ho...
# 2  Why do 5-star hotels hesitate to allow a girl ...
# 3  What do 5-Star hotels do to keep out bedbugs b...
# 4  How does a 5 star hotel make its profit given ...
# 5  Do 5 star hotels allow outside liquor in limit...
# 6  What are the differences among 3 star, 5 star ...
# 7  What are the things complimentary in a 5 star ...
# 8           Do five-star hotels allow outside food?
# 9  What is the difference between 3,4 and 5 star ...

# %%
# Export the data to file
df.to_csv(keyword1 + "My_Questions.csv")
