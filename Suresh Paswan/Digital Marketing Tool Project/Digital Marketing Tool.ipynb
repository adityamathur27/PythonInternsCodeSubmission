# %%
import requests  #Liberary for HTTP request
import pandas as pd  #Liberary for represent response in tabular form
import json    #Liberary for data representation during transmissiom

from datetime import date, timedelta  #Liberary for Date management

# %%
# taking keyword from user
keyword = input('Enter a Keyword: ')
keyword1 = keyword
# searching keyword in quora
# keyword = keyword + " site:quora.com site:reditt.com"

# making multiple search site
sites = ['quora.com', 'reditt.com']

#Globle Variables
question_list = []
snippet_list = []
link_list = []

for site in sites:
    keyword = keyword +" site:"+site
    
    # search on google using API
    # API Key = AIzaSyAFB7TsgNf4xiIgOJydgsUZvFK-62OTNj0
    google_url = "https://www.googleapis.com/customsearch/v1/?key=AIzaSyAFB7TsgNf4xiIgOJydgsUZvFK-62OTNj0&cx=71085f10797e942d0"
    google_url = google_url + "&q=" + keyword
    #print("Google URL: "+ google_url)    
    
    # Send a network request to google
    response = requests.get(google_url)
    #print('Respons: '+ str(response.text))
    
    # convert Jason response string into Jason obj
    jason_resp = json.loads(response.text)
    #search_time = str(jason_resp["searchInformation"]['searchTime'])
    total_result = int(jason_resp["searchInformation"]['totalResults'])
    #print('Search Time:'+ search_time +' & Search Result: ' + total_result)
    
    #Get the start index of next page
    #nextIndex = jason_resp["queries"]["nextPage"][0]["startIndex"]
    
    #Loop through all responses
    total_pages = round(total_result /10)
    
    try:
        for item in jason_resp["items"]:
            temp = item
            title = item["title"]
            title = title.replace(" - Quora","")        
            question_list.append(title)                
            link = temp["link"]
            link_list.append(link)            
            snippet = temp["snippet"]
            snippet_list.append(snippet)
            
            
    except Exception as e:
        pass
    
    # reset the keyword
    keyword = keyword1
    
#question_list
question_dict = {"Questions": question_list,"Links":link_list,"Snippet":snippet_list}
df = pd.DataFrame(data = question_dict)
df
#question_dict
# Out:
# Enter a Keyword: weight loss
#                                            Questions  \
# 0             What are the best ways to lose weight?
# 1          Is a ketogenic diet good for weight loss?
# 2  Is Diet Coke (or other diet sodas) good or bad...
# 3  Which K-pop stars or idols had the craziest we...
# 4            Is water fasting weight loss permanent?
# 5  I'm on a weight loss diet. Is drinking Coke Ze...
# 6  What is the best thing to do to maximize weigh...
# 7            Is fried plantain good for weight loss?
# 8  Can running a total of 4 miles a day help weig...
# 9  Is it unusual to hit a weight loss plateau of ...
#
#                                                Links  \
# 0  https://www.quora.com/What-are-the-best-ways-t...
# 1  https://www.quora.com/Is-a-ketogenic-diet-good...
# 2  https://www.quora.com/Is-Diet-Coke-or-other-di...
# 3  https://www.quora.com/Which-K-pop-stars-or-ido...
# 4  https://www.quora.com/Is-water-fasting-weight-...
# ...

# %%
#Export the data to a file
df.to_csv(keyword1 + " questions.csv")
